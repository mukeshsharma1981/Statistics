# %% [markdown]
# <a href="https://colab.research.google.com/github/mukeshsharma1981/Statistics/blob/main/Stats_3_Continious_Probability_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Continious Probability Models
#
# 1. Uniform model
# 2. Normal model
# 3. Exponential model
# 4. Gamma model
# 5. Chi-Square (χ2) model
# 6. Beta model

# %% [markdown]
# ## Uniform model graph
#
# The pdf of three uniform distributions are plotted in R as follows:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Continious Probability Model - Uniform Model
#
# 1. Data Simulation - runif(s,a,b)
# *  s=sample size
# *  a=the minimum value of the random variable
# *  b=the maximum value of the random variable
#
#
#
# 2. Probability density Function (**pdf**) - dunif(j,a,b)
# *  j=is the possible value of the ramdon variable
# *  a=the minimum value of the random variable
# *  b=the maximum value of the random variable
#
#
#
# 3. Cumulative Distribution Function (**cdf**) - punif(j,a,b)
# *  j=is the possible value of the ramdon variable
# *  a=the minimum value of the random variable
# *  b=the maximum value of the random variable

# %% [markdown]
# ## Example
# Let random variable X be distributed with the Uniform model U(a=4,b=6.5).
#
# a) Simulate 100 samples from the above model.
#
# b) Find P(X<5.3).

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# s=100;a=4;b=6.5
# # a
# print(runif(s,a,b))
#
# # b
# print(punif(5.3,a,b))
# Out:
#   [1] 6.368657 5.627001 4.294743 5.770590 6.267828 4.348521 5.680812 5.321090
#   [9] 5.189859 5.072012 6.454439 4.504424 5.003578 5.435875 4.779634 5.926207
#  [17] 6.462475 5.129637 5.647189 6.034002 4.115104 4.107394 5.173689 4.954372
#  [25] 6.185867 5.348235 4.297116 5.654209 5.768169 4.524800 4.780340 5.995379
#  [33] 6.401997 5.328481 5.926896 4.583499 4.544514 6.436272 4.718078 4.130058
#  [41] 4.874008 6.051165 6.083787 4.713508 5.230570 4.287051 5.250341 5.104784
#  [49] 5.405709 5.419688 5.942120 5.261327 4.588592 5.202277 6.170302 5.225326
#  [57] 5.569117 6.404711 4.064603 4.733577 5.270910 5.198783 5.891995 5.446841
#  [65] 5.037274 5.299041 5.406874 5.819966 5.755039 5.461678 6.064564 4.736961
#  [73] 5.141754 6.326639 6.216881 5.200545 5.169003 4.554951 4.963443 4.400551
#  [81] 4.467439 5.969493 6.183505 4.142077 6.477278 5.498123 4.821921 4.581533
#  [89] 5.134611 5.639110 5.889900 5.111321 5.321246 5.659784 5.386019 4.543855
# ...

# %% [markdown]
# ## Example
# Let the random variable X be distributed with a standard uniform model.
#
# Find P(X<0.25).

# %%
# %%R
# print(punif(0.25,0,1))
# Out:
# [1] 0.25

# %% [markdown]
# # Normal model graph
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Continious Probability Model - Normal Model
#
# 1. Data Simulation - rnorm(s, µ, σ)
# *  s=sample size
# *  µ=the parameter mean
# *  σ=the parameter standard deviation
#
#
#
# 2. Probability density Function (**pdf**) - dnorm(j, µ, σ)
# *  j=is the possible value of the ramdon variable
# *  µ=the parameter mean
# *  σ=the parameter standard deviation
#
#
#
# 3. Cumulative Distribution Function (**cdf**) - CDF=P(X<=j) =  pnorm(j, µ, σ)
# *  j=is the possible value of the ramdon variable
# *  µ=the parameter mean
# *  σ=the parameter standard deviation

# %% [markdown]
# ## Example
# Let X be distributed with N(µ=1, σ=0.5).
#
# a) Simulate 20 samples from this model.
#
# b) Find P(0.7 < X < 1.2).

# %%
# %%R
# s=20;mu=1; sd=0.5
#
# # a
# rnorm(s, mu, sd)
#
# # b
# pnorm(1.2,mu,sd)-pnorm(0.7,mu,sd)
# Out:
# [1] 0.3811686

# %% [markdown]
# ## Example
#
# For a certain type of computer, the length of time between charges of the battery is normally distributed with a mean of 50 hours and a standard deviation of 15 hours.
#
# a) Find the probability that the length of time is between 50 and 70 hours.
#
# b) Write a code to plot the above normal pdf.

# %%
# %%R
# mu=50;sigma=15
# pnorm(70,mu,sigma)-pnorm(50,mu,sigma)
# Out:
# [1] 0.4087888

# %%
# %%R
#
# # b
# X=seq(10,90,0.1)
# plot(X,dnorm(X,mu,sigma), type='l')

# %% [markdown]
# # Exponential Model
#
# The pdf of five exponential distributions are plotted in R as follows:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Continious Probability Model - Exponential Model
#
# 1. Data Simulation - rexp(s, λ)
# *  s=sample size
# *  λ (Lambda)= the parameter rate
#
#
#
# 2. Probability density Function (**pdf**) - rexp(j, λ)
# *  j=is the possible value of the ramdon variable
# *  λ (Lambda)= the parameter rate
#
#
#
# 3. Cumulative Distribution Function (**cdf**) - CDF=P(X<=j) = pexp(j,λ)
# *  j=is the possible value of the ramdon variable
# *  λ (Lambda)= the parameter rate

# %% [markdown]
# ## Example
# Let X be distributed with Exp(λ=2.4).
#
# a) Simulate 10 samples from this model.
#
# b) Find P(X>3.5).

# %%
# %%R
# lam=2.4;s=10
#
# # a
# rexp(s,lam)
# Out:
#  [1] 0.56612282 0.12681745 0.61074712 0.12222818 0.44128549 0.42159417
#  [7] 0.16043202 0.47601060 0.02244683 0.67275948

# %%
# %%R
# # b
# 1-pexp(3.5,lam)
# Out:
# [1] 0.0002248673

# %% [markdown]
# # Gamma Model
#
# The pdf of five Gamma distributions are plotted in R as follows:
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Continious Probability Model - Gamma Model
#
# 1. Data Simulation - rgamma(s, a, λ)
# *  s=sample size
# *  a=the parameter counter
# *  λ (Lambda)= the parameter rate
#
#
#
# 2. Probability density Function (**pdf**) - dgamma(j, a, λ)
# *  j=is the possible value of the ramdon variable
# *  a=the parameter counter
# *  λ (Lambda)= the parameter rate
#
#
#
# 3. Cumulative Distribution Function (**cdf**) - CDF=P(X<=j) = pgamma(j, α, λ)
# *  j=is the possible value of the ramdon variable
# *  a=the parameter counter
# *  λ (Lambda)= the parameter rate

# %% [markdown]
# ## Example
# Let us assume a multiagent system constitutes eight components in a series configuration. Each component measures the local capacity (ci ) with the rate λi =0.5+i, i=1,...,8.
#
# a) If y=c1+c2+...+c8, what is the model of the system’s capacity?
#
# b) Find p(y>1/5).

# %%
# %%R
# alpha=8
# lam=0
# for (i in 1:8){
#     lam=lam+0.5+i
# }
# lam
# Out:
# [1] 40

# %%
# %%R
# 1-pgamma(1/5,alpha, lam)
# Out:
# [1] 0.4529608

# %% [markdown]
# Chi-Square (χ2) model
#
# The pdf of Chi-Square (χ2) model is plotted for different values of k in R:
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Continious Probability Model - Chi-Square model
#
# 1. Data Simulation - rchisq(s, k)
# *  s=sample size
# *  k=the parameter, degree of freedom
#
#
#
# 2. Probability density Function (**pdf**) - dchisq(j,k)
# *  j=is the possible value of the ramdon variable
# *  k=the parameter, degree of freedom
#
#
#
# 3. Cumulative Distribution Function (**cdf**) - CDF=P(X<=j) = pchisq(j,k)
# *  j=is the possible value of the ramdon variable
# *  k=the parameter, degree of freedom

# %% [markdown]
# ## Example
#
# Let X be a Chi-Square random variable with k=3.
#
# a) Generate 20 samples for X.
#
# b) Find p(0.2<X<2.4).
#
# c) Plot the pdf of X.

# %%
# %%R
# k=3;s=20
#
# # a
# print(rchisq(s, k))
#
# # b
# print(pchisq(2.4,k)-pchisq(0.2,k))
# Out:
#  [1]  2.7234217  0.1255445  2.8574453  5.3252727 11.2921864  8.5635976
#  [7]  6.3887692  3.9699825  0.5020851  2.6308786  1.5962453  0.4439222
# [13]  1.8242027  1.2979574  5.4500278  6.8562044  0.7927709  5.1082352
# [19]  2.2944870  1.2635550
# [1] 0.4839547

# %%
# %%R
# # c
# x <- seq(0,20,100)
# k=3
#
# plot(x, dchisq(x,k), type='l', lyt=2, xlab='x value', ylab='y value', main='chi-square pdf for k=3')

# %% [markdown]
# # Beta model
#
# The pdf of the Beta model is plotted for different values of (α,β) in R as follows:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Continious Probability Model - Beta model
#
# 1. Data Simulation - rbeta(s,α,β)
# *  s=sample size
# *  α=the first shaping parameter
# *  β=the second shaping parameter
#
#
# 2. Probability density Function (**pdf**) - dbeta(j,α,β)
# *  j=is the possible value of the ramdon variable
# *  α=the first shaping parameter
# *  β=the second shaping parameter
#
#
#
# 3. Cumulative Distribution Function (**cdf**) - CDF=P(X<=j) =pbeta(j,α,β)
# *  j=is the possible value of the ramdon variable
# *  α=the first shaping parameter
# *  β=the second shaping parameter

# %% [markdown]
# ## Example
# In a MSN, four sensors are connected independently. Let p be the probability of the sensor's connection distributed with Beta(2,5).
#
# a) Generate 10 samples of p and compute the mean of simulated data.
#
# b) Using the estimated value of p, find the probability that at least two sensors are connected in MSN.

# %%
# %%R
# s=10;alpha=2;beta=5
#
# # a
# sim=rbeta(s,alpha,beta)
# phat=mean(sim)
#
# # b
# a=1 - pbinom(1,4,phat)
# a
# Out:
# [1] 0.1886607
